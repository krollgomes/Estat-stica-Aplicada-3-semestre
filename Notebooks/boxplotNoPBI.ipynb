# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# O Power BI cria o DataFrame 'dataset' com os campos selecionados
# Configura o estilo visual do seaborn
sns.set_theme(style="whitegrid")
# Cria o boxplot
# x define as categorias (Bairro)
# y define a variável numérica (Preco_m2)
# palette define as cores
plt.figure(figsize=(10, 6)) # Define o tamanho da figura
ax = sns.boxplot(x='Bairro', y='Preco_m2', data=dataset, palette="Set2")

# Adiciona pontos individuais (swarmplot) sobre o boxplot
#para mostrar a densidade dos dados
sns.swarmplot(x='Bairro', y='Preco_m2', data=dataset, color=".25", size=4)

# Personaliza títulos e rótulos
plt.title('Distribuição de Preço/m² por Bairro em São Paulo', fontsize=14)
plt.xlabel('Bairro', fontsize=12)
plt.ylabel('Preço por m² (R$)', fontsize=12)

# Exibe o gráfico no Power BI
plt.show()
